# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\hoc13\AppData\Local\Temp\ipykernel_13732\2080034654.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('titanic.csv')

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Разбейте исходную таблицу на 2: по полу пассажиров

# %%
female = data[data['Sex'] == 'female'].dropna()
female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
male = data[data['Sex'] == 'male'].dropna()
male
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                   ...
# 806          807         0       1                Andrews, Mr. Thomas Jr
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# # Удалите пустые строки или заполните их соответствующими символами

# %%
data = data.dropna()
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Построить гистограмму распределения пассажиров по возрасту

# %%
data['Age'].plot(kind='hist', bins=50, alpha=0.7)
plt.xlabel('Age')
plt.ylabel('People number')
# Out:
# Text(0, 0.5, 'People number')

# %% [markdown]
# # Вычислите мин и макс, среднее, моду, медиану возраста пассажира каждого пола

# %%
print(male['Age'].min())
print(male['Age'].max())
print(male['Age'].mean())
print(male['Age'].mode()[0])
print(male['Age'].median())
# Out:
# 0.92
# 80.0
# 38.45178947368421
# 36.0
# 37.0

# %%
print(female['Age'].min())
print(female['Age'].max())
print(female['Age'].mean())
print(female['Age'].mode()[0])
print(female['Age'].median())
# Out:
# 2.0
# 63.0
# 32.67613636363637
# 24.0
# 32.25

# %% [markdown]
# # визуализировать возраст при помощи различных настроек метода plot

# %%
plt.scatter(male.index, male['Age'], label='male', alpha=0.7)
plt.scatter(female.index, female['Age'], label='female', alpha=0.7)

plt.ylabel('Age')
plt.legend()
plt.show()

# %%
male['Age'].plot(kind='hist', alpha=0.4, label='Мужчины', bins=10)
female['Age'].plot(kind='hist', alpha=0.4, label='Женщины', bins=10)

plt.xlabel('age')
plt.ylabel('freq')
plt.legend()
plt.show()
