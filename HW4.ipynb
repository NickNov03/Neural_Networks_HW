# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.20.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in c:\users\hoc13\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (1.26.3)
# Collecting torch==2.5.1 (from torchvision)
#   Downloading torch-2.5.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hoc13\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: filelock in c:\users\hoc13\appdata\local\programs\python\python312\lib\site-packages (from torch==2.5.1->torchvision) (3.13.1)
# Collecting typing-extensions>=4.8.0 (from torch==2.5.1->torchvision)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch==2.5.1->torchvision)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\hoc13\appdata\local\programs\python\python312\lib\site-packages (from torch==2.5.1->torchvision) (3.1.3)
# Collecting fsspec (from torch==2.5.1->torchvision)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\users\hoc13\appdata\local\programs\python\python312\lib\site-packages (from torch==2.5.1->torchvision) (69.0.3)
# Collecting sympy==1.13.1 (from torch==2.5.1->torchvision)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch==2.5.1->torchvision)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hoc13\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch==2.5.1->torchvision) (2.1.5)
# Downloading torchvision-0.20.1-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.6 MB 1.4 MB/s eta 0:00:02
#    --- ------------------------------------ 0.1/1.6 MB 1.4 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.6 MB 2.0 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.6 MB 2.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.7/1.6 MB 2.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.7 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp312-cp312-win_amd64.whl (203.0 MB)
#    ---------------------------------------- 0.0/203.0 MB ? eta -:--:--
#    ---------------------------------------- 1.6/203.0 MB 98.6 MB/s eta 0:00:03
#     --------------------------------------- 4.0/203.0 MB 51.1 MB/s eta 0:00:04
#    - -------------------------------------- 7.1/203.0 MB 56.4 MB/s eta 0:00:04
#    - -------------------------------------- 7.1/203.0 MB 50.3 MB/s eta 0:00:04
#    - -------------------------------------- 7.1/203.0 MB 50.3 MB/s eta 0:00:04
#    - -------------------------------------- 7.1/203.0 MB 50.3 MB/s eta 0:00:04
#    - -------------------------------------- 9.5/203.0 MB 35.6 MB/s eta 0:00:06
#    - -------------------------------------- 9.5/203.0 MB 35.6 MB/s eta 0:00:06
#    -- ------------------------------------- 11.0/203.0 MB 31.2 MB/s eta 0:00:07
#    -- ------------------------------------- 12.3/203.0 MB 31.2 MB/s eta 0:00:07
#    -- ------------------------------------- 13.8/203.0 MB 28.4 MB/s eta 0:00:07
#    -- ------------------------------------- 13.8/203.0 MB 28.4 MB/s eta 0:00:07
#    --- ------------------------------------ 15.7/203.0 MB 26.2 MB/s eta 0:00:08
#    --- ------------------------------------ 18.0/203.0 MB 34.4 MB/s eta 0:00:06
#    --- ------------------------------------ 19.0/203.0 MB 28.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 20.4/203.0 MB 29.7 MB/s eta 0:00:07
#    ---- ----------------------------------- 24.0/203.0 MB 36.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 28.0/203.0 MB 50.4 MB/s eta 0:00:04
#    ------ --------------------------------- 31.5/203.0 MB 72.6 MB/s eta 0:00:03
#    ------ --------------------------------- 34.1/203.0 MB 72.6 MB/s eta 0:00:03
#    ------- -------------------------------- 37.4/203.0 MB 72.6 MB/s eta 0:00:03
#    -------- ------------------------------- 41.2/203.0 MB 81.8 MB/s eta 0:00:02
#    -------- ------------------------------- 45.1/203.0 MB 81.8 MB/s eta 0:00:02
#    --------- ------------------------------ 48.8/203.0 MB 72.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 51.0/203.0 MB 73.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 51.0/203.0 MB 73.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 51.0/203.0 MB 73.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 52.9/203.0 MB 40.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 53.6/203.0 MB 34.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 54.0/203.0 MB 31.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 55.2/203.0 MB 29.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 56.2/203.0 MB 27.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 57.4/203.0 MB 23.4 MB/s eta 0:00:07
#    ----------- ---------------------------- 59.9/203.0 MB 23.4 MB/s eta 0:00:07
#    ------------ --------------------------- 62.2/203.0 MB 31.2 MB/s eta 0:00:05
#    ------------ --------------------------- 64.4/203.0 MB 38.6 MB/s eta 0:00:04
#    ------------- -------------------------- 67.0/203.0 MB 54.7 MB/s eta 0:00:03
#    ------------- -------------------------- 69.4/203.0 MB 54.7 MB/s eta 0:00:03
#    -------------- ------------------------- 72.1/203.0 MB 54.4 MB/s eta 0:00:03
#    -------------- ------------------------- 74.9/203.0 MB 54.4 MB/s eta 0:00:03
#    --------------- ------------------------ 77.5/203.0 MB 54.7 MB/s eta 0:00:03
#    --------------- ------------------------ 79.5/203.0 MB 54.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 82.0/203.0 MB 54.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 84.2/203.0 MB 50.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 85.5/203.0 MB 54.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 86.2/203.0 MB 40.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 88.2/203.0 MB 40.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 90.9/203.0 MB 40.9 MB/s eta 0:00:03
#    ------------------ --------------------- 92.7/203.0 MB 40.9 MB/s eta 0:00:03
#    ------------------ --------------------- 94.2/203.0 MB 38.6 MB/s eta 0:00:03
#    ------------------ --------------------- 96.1/203.0 MB 50.4 MB/s eta 0:00:03
#    ------------------- -------------------- 97.6/203.0 MB 43.7 MB/s eta 0:00:03
#    ------------------- -------------------- 99.4/203.0 MB 40.9 MB/s eta 0:00:03
#    ------------------- ------------------- 101.2/203.0 MB 38.5 MB/s eta 0:00:03
#    ------------------- ------------------- 102.9/203.0 MB 38.5 MB/s eta 0:00:03
#    -------------------- ------------------ 104.9/203.0 MB 38.5 MB/s eta 0:00:03
#    -------------------- ------------------ 106.1/203.0 MB 38.5 MB/s eta 0:00:03
#    -------------------- ------------------ 108.4/203.0 MB 38.6 MB/s eta 0:00:03
#    --------------------- ----------------- 110.2/203.0 MB 38.6 MB/s eta 0:00:03
#    --------------------- ----------------- 112.2/203.0 MB 40.9 MB/s eta 0:00:03
#    --------------------- ----------------- 114.3/203.0 MB 38.5 MB/s eta 0:00:03
#    ---------------------- ---------------- 116.3/203.0 MB 38.6 MB/s eta 0:00:03
#    ---------------------- ---------------- 118.2/203.0 MB 40.9 MB/s eta 0:00:03
#    ----------------------- --------------- 120.2/203.0 MB 38.6 MB/s eta 0:00:03
#    ----------------------- --------------- 122.2/203.0 MB 40.9 MB/s eta 0:00:02
#    ----------------------- --------------- 124.1/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------ -------------- 126.0/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------ -------------- 127.3/203.0 MB 38.5 MB/s eta 0:00:02
#    ------------------------ -------------- 129.3/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------- ------------- 131.3/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------- ------------- 133.3/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------- ------------- 135.2/203.0 MB 38.5 MB/s eta 0:00:02
#    -------------------------- ------------ 137.3/203.0 MB 40.9 MB/s eta 0:00:02
#    -------------------------- ------------ 139.4/203.0 MB 40.9 MB/s eta 0:00:02
#    --------------------------- ----------- 140.9/203.0 MB 40.9 MB/s eta 0:00:02
#    --------------------------- ----------- 142.8/203.0 MB 38.6 MB/s eta 0:00:02
#    --------------------------- ----------- 144.8/203.0 MB 38.6 MB/s eta 0:00:02
#    ---------------------------- ---------- 146.9/203.0 MB 43.7 MB/s eta 0:00:02
#    ---------------------------- ---------- 148.9/203.0 MB 40.9 MB/s eta 0:00:02
#    ---------------------------- ---------- 150.9/203.0 MB 43.5 MB/s eta 0:00:02
#    ----------------------------- --------- 152.6/203.0 MB 40.9 MB/s eta 0:00:02
#    ----------------------------- --------- 154.2/203.0 MB 43.7 MB/s eta 0:00:02
#    ------------------------------ -------- 156.4/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------------ -------- 158.4/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------------ -------- 160.1/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------------- ------- 162.0/203.0 MB 40.9 MB/s eta 0:00:02
#    ------------------------------- ------- 163.7/203.0 MB 38.5 MB/s eta 0:00:02
#    ------------------------------- ------- 165.6/203.0 MB 38.5 MB/s eta 0:00:01
#    -------------------------------- ------ 167.8/203.0 MB 40.9 MB/s eta 0:00:01
#    -------------------------------- ------ 169.8/203.0 MB 40.9 MB/s eta 0:00:01
#    --------------------------------- ----- 171.8/203.0 MB 43.7 MB/s eta 0:00:01
#    --------------------------------- ----- 173.8/203.0 MB 43.7 MB/s eta 0:00:01
#    --------------------------------- ----- 176.0/203.0 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 177.8/203.0 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 179.6/203.0 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 181.6/203.0 MB 43.5 MB/s eta 0:00:01
#    ----------------------------------- --- 183.7/203.0 MB 43.5 MB/s eta 0:00:01
#    ----------------------------------- --- 185.9/203.0 MB 43.5 MB/s eta 0:00:01
#    ------------------------------------ -- 187.6/203.0 MB 40.9 MB/s eta 0:00:01
#    ------------------------------------ -- 189.4/203.0 MB 43.7 MB/s eta 0:00:01
#    ------------------------------------ -- 191.3/203.0 MB 40.9 MB/s eta 0:00:01
#    ------------------------------------- - 193.1/203.0 MB 43.7 MB/s eta 0:00:01
#    ------------------------------------- - 195.1/203.0 MB 43.7 MB/s eta 0:00:01
#    ------------------------------------- - 196.8/203.0 MB 43.7 MB/s eta 0:00:01
#    --------------------------------------  198.8/203.0 MB 43.7 MB/s eta 0:00:01
#    --------------------------------------  199.2/203.0 MB 43.7 MB/s eta 0:00:01
#    --------------------------------------  200.4/203.0 MB 36.4 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    --------------------------------------  203.0/203.0 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------- 203.0/203.0 MB 2.8 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --------- ------------------------------ 1.5/6.2 MB 31.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.5/6.2 MB 32.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.5/6.2 MB 32.0 MB/s eta 0:00:01
#    ------------------------------- -------- 4.9/6.2 MB 31.0 MB/s eta 0:00:01
#    -------------------------------------- - 5.9/6.2 MB 31.3 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 23.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ---------------------------------------- 0.0/179.6 kB ? eta -:--:--
#    ---------------------------------------- 179.6/179.6 kB ? eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -------------------------------------- - 1.7/1.7 MB 35.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 22.0 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    --------------------------------------- 536.2/536.2 kB 32.9 MB/s eta 0:00:00
# Installing collected packages: mpmath, typing-extensions, sympy, networkx, fsspec, torch, torchvision
# Successfully installed fsspec-2024.10.0 mpmath-1.3.0 networkx-3.4.2 sympy-1.13.1 torch-2.5.1 torchvision-0.20.1 typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

def get_data(is_train, path = 'data', transform = ToTensor()):
    return datasets.FashionMNIST(
                root=path,
                train=is_train,
                download=True,
                transform=transform
            )

# %%
BATCH_SIZE = 64

LEARNING_RATE = 1E-3
EPOCHS = 50

# %%
from torch import nn

class NeuralNetwork(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
def train_loop(dataloader, model, loss_fn, optimizer):

    size = len(dataloader.dataset)
    model.train()
    sum_loss = 0

    for batch, (X, y) in enumerate(dataloader):

        pred = model(X)
        loss = loss_fn(pred, y)
        sum_loss += loss.item()

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            current = batch * len(X)
            print(f'loss: {loss.item():>7f}  [{current:>5d}/{size:>5d}]')
            
    return sum_loss / len(dataloader)

# %%
from torch import no_grad, float

def test_loop(dataloader, model, loss_fn):

    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with no_grad():

        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(float).sum().item()

    test_loss /= num_batches
    correct /= size

    print(f'Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n')

    return test_loss

# %%
def run_training(epochs, train_dataloader, test_dataloader, model, loss_fn, optimizer):

    test_losses = []

    for t in range(epochs):
        
        print(f'Epoch {t+1}\n-------------------------------')
        train_loss = train_loop(train_dataloader, model, loss_fn, optimizer)
        test_loss = test_loop(test_dataloader, model, loss_fn)
        test_losses.append(test_loss)

    print('Done!')

    return test_losses

# %%
training_data = get_data(is_train=True)
test_data = get_data(is_train=False)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 0.1%
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100.0%
# Extracting data\FashionMNIST\raw\train-images-idx3-ubyte.gz to data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100.0%
# Extracting data\FashionMNIST\raw\train-labels-idx1-ubyte.gz to data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100.0%
# Extracting data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to data\FashionMNIST\raw

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
from torch.optim import SGD, RMSprop, Adam

model = NeuralNetwork()
optimizer_sgd = SGD(model.parameters(), lr=LEARNING_RATE)
print('Training with SGD optimizer')
test_loss_sgd = run_training(EPOCHS, train_dataloader, test_dataloader, model, nn.CrossEntropyLoss(), optimizer_sgd)
# Out:
# Training with SGD optimizer
# Epoch 1
# -------------------------------
# loss: 2.298629  [    0/60000]
# loss: 2.291268  [ 6400/60000]
# loss: 2.274098  [12800/60000]
# loss: 2.264780  [19200/60000]
# loss: 2.244391  [25600/60000]
# loss: 2.221597  [32000/60000]
# loss: 2.228859  [38400/60000]
# loss: 2.193851  [44800/60000]
# loss: 2.191838  [51200/60000]
# loss: 2.159862  [57600/60000]
# Test Error:
#  Accuracy: 48.1%, Avg loss: 2.150171
#
# Epoch 2
# -------------------------------
# loss: 2.160922  [    0/60000]
# loss: 2.153073  [ 6400/60000]
# loss: 2.087641  [12800/60000]
# loss: 2.099802  [19200/60000]
# loss: 2.054034  [25600/60000]
# loss: 1.991309  [32000/60000]
# loss: 2.027074  [38400/60000]
# loss: 1.938037  [44800/60000]
# loss: 1.946192  [51200/60000]
# loss: 1.876931  [57600/60000]
# Test Error:
#  Accuracy: 57.0%, Avg loss: 1.864214
#
# Epoch 3
# -------------------------------
# loss: 1.899608  [    0/60000]
# loss: 1.874450  [ 6400/60000]
# loss: 1.739992  [12800/60000]
# loss: 1.784149  [19200/60000]
# loss: 1.692076  [25600/60000]
# loss: 1.635496  [32000/60000]
# loss: 1.672658  [38400/60000]
# loss: 1.566274  [44800/60000]
# loss: 1.592989  [51200/60000]
# loss: 1.499419  [57600/60000]
# Test Error:
#  Accuracy: 60.9%, Avg loss: 1.505225
#
# Epoch 4
# -------------------------------
# loss: 1.567364  [    0/60000]
# loss: 1.545113  [ 6400/60000]
# loss: 1.385531  [12800/60000]
# loss: 1.461861  [19200/60000]
# loss: 1.353759  [25600/60000]
# loss: 1.345011  [32000/60000]
# loss: 1.371263  [38400/60000]
# loss: 1.293372  [44800/60000]
# loss: 1.325747  [51200/60000]
# loss: 1.235439  [57600/60000]
# Test Error:
#  Accuracy: 63.2%, Avg loss: 1.252831
#
# Epoch 5
# -------------------------------
# loss: 1.321463  [    0/60000]
# loss: 1.316185  [ 6400/60000]
# loss: 1.147162  [12800/60000]
# loss: 1.251552  [19200/60000]
# loss: 1.128269  [25600/60000]
# loss: 1.154196  [32000/60000]
# loss: 1.180731  [38400/60000]
# loss: 1.121299  [44800/60000]
# loss: 1.155827  [51200/60000]
# loss: 1.075281  [57600/60000]
# Test Error:
#  Accuracy: 64.5%, Avg loss: 1.091357
#
# Epoch 6
# -------------------------------
# loss: 1.154315  [    0/60000]
# loss: 1.167181  [ 6400/60000]
# loss: 0.985338  [12800/60000]
# loss: 1.115430  [19200/60000]
# loss: 0.985240  [25600/60000]
# loss: 1.021907  [32000/60000]
# loss: 1.058619  [38400/60000]
# loss: 1.008561  [44800/60000]
# loss: 1.042366  [51200/60000]
# loss: 0.972210  [57600/60000]
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.984600
#
# Epoch 7
# -------------------------------
# loss: 1.035151  [    0/60000]
# loss: 1.067969  [ 6400/60000]
# loss: 0.871777  [12800/60000]
# loss: 1.023880  [19200/60000]
# loss: 0.893807  [25600/60000]
# loss: 0.927311  [32000/60000]
# loss: 0.977258  [38400/60000]
# loss: 0.934047  [44800/60000]
# loss: 0.963191  [51200/60000]
# loss: 0.902615  [57600/60000]
# Test Error:
#  Accuracy: 66.9%, Avg loss: 0.911295
#
# Epoch 8
# -------------------------------
# loss: 0.946893  [    0/60000]
# loss: 0.998017  [ 6400/60000]
# loss: 0.790252  [12800/60000]
# loss: 0.959129  [19200/60000]
# loss: 0.832633  [25600/60000]
# loss: 0.858082  [32000/60000]
# loss: 0.920165  [38400/60000]
# loss: 0.884078  [44800/60000]
# loss: 0.906111  [51200/60000]
# loss: 0.852899  [57600/60000]
# Test Error:
#  Accuracy: 68.2%, Avg loss: 0.858561
#
# Epoch 9
# -------------------------------
# loss: 0.878937  [    0/60000]
# loss: 0.945354  [ 6400/60000]
# loss: 0.729556  [12800/60000]
# loss: 0.911125  [19200/60000]
# loss: 0.789463  [25600/60000]
# loss: 0.806442  [32000/60000]
# loss: 0.877415  [38400/60000]
# loss: 0.849238  [44800/60000]
# loss: 0.863692  [51200/60000]
# loss: 0.815060  [57600/60000]
# Test Error:
#  Accuracy: 69.4%, Avg loss: 0.818870
#
# Epoch 10
# -------------------------------
# loss: 0.825161  [    0/60000]
# loss: 0.903193  [ 6400/60000]
# loss: 0.682562  [12800/60000]
# loss: 0.874432  [19200/60000]
# loss: 0.756988  [25600/60000]
# loss: 0.767345  [32000/60000]
# loss: 0.843443  [38400/60000]
# loss: 0.823633  [44800/60000]
# loss: 0.830972  [51200/60000]
# loss: 0.784948  [57600/60000]
# Test Error:
#  Accuracy: 70.6%, Avg loss: 0.787582
#
# Epoch 11
# -------------------------------
# loss: 0.780821  [    0/60000]
# loss: 0.867832  [ 6400/60000]
# loss: 0.644855  [12800/60000]
# loss: 0.845540  [19200/60000]
# loss: 0.731111  [25600/60000]
# loss: 0.736932  [32000/60000]
# loss: 0.815042  [38400/60000]
# loss: 0.803626  [44800/60000]
# loss: 0.804597  [51200/60000]
# loss: 0.760044  [57600/60000]
# Test Error:
#  Accuracy: 71.8%, Avg loss: 0.761760
#
# Epoch 12
# -------------------------------
# loss: 0.743165  [    0/60000]
# loss: 0.836966  [ 6400/60000]
# loss: 0.613376  [12800/60000]
# loss: 0.821830  [19200/60000]
# loss: 0.709667  [25600/60000]
# loss: 0.712539  [32000/60000]
# loss: 0.790047  [38400/60000]
# loss: 0.787055  [44800/60000]
# loss: 0.782585  [51200/60000]
# loss: 0.738764  [57600/60000]
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.739587
#
# Epoch 13
# -------------------------------
# loss: 0.710418  [    0/60000]
# loss: 0.809345  [ 6400/60000]
# loss: 0.586606  [12800/60000]
# loss: 0.801867  [19200/60000]
# loss: 0.691180  [25600/60000]
# loss: 0.692436  [32000/60000]
# loss: 0.767549  [38400/60000]
# loss: 0.772484  [44800/60000]
# loss: 0.763479  [51200/60000]
# loss: 0.720011  [57600/60000]
# Test Error:
#  Accuracy: 74.0%, Avg loss: 0.719937
#
# Epoch 14
# -------------------------------
# loss: 0.681415  [    0/60000]
# loss: 0.784203  [ 6400/60000]
# loss: 0.563251  [12800/60000]
# loss: 0.784450  [19200/60000]
# loss: 0.675008  [25600/60000]
# loss: 0.675473  [32000/60000]
# loss: 0.746896  [38400/60000]
# loss: 0.759307  [44800/60000]
# loss: 0.746558  [51200/60000]
# loss: 0.703069  [57600/60000]
# Test Error:
#  Accuracy: 74.9%, Avg loss: 0.702120
#
# Epoch 15
# -------------------------------
# loss: 0.655244  [    0/60000]
# loss: 0.761137  [ 6400/60000]
# loss: 0.542526  [12800/60000]
# loss: 0.768797  [19200/60000]
# loss: 0.660722  [25600/60000]
# loss: 0.660849  [32000/60000]
# loss: 0.727673  [38400/60000]
# loss: 0.747137  [44800/60000]
# loss: 0.731440  [51200/60000]
# loss: 0.687540  [57600/60000]
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.685760
#
# Epoch 16
# -------------------------------
# loss: 0.631509  [    0/60000]
# loss: 0.739863  [ 6400/60000]
# loss: 0.523948  [12800/60000]
# loss: 0.754555  [19200/60000]
# loss: 0.647931  [25600/60000]
# loss: 0.648071  [32000/60000]
# loss: 0.709571  [38400/60000]
# loss: 0.735886  [44800/60000]
# loss: 0.717787  [51200/60000]
# loss: 0.673199  [57600/60000]
# Test Error:
#  Accuracy: 76.3%, Avg loss: 0.670629
#
# Epoch 17
# -------------------------------
# loss: 0.609981  [    0/60000]
# loss: 0.720121  [ 6400/60000]
# loss: 0.507274  [12800/60000]
# loss: 0.741423  [19200/60000]
# loss: 0.636389  [25600/60000]
# loss: 0.636727  [32000/60000]
# loss: 0.692691  [38400/60000]
# loss: 0.725635  [44800/60000]
# loss: 0.705569  [51200/60000]
# loss: 0.659817  [57600/60000]
# Test Error:
#  Accuracy: 77.0%, Avg loss: 0.656596
#
# Epoch 18
# -------------------------------
# loss: 0.590419  [    0/60000]
# loss: 0.701859  [ 6400/60000]
# loss: 0.492176  [12800/60000]
# loss: 0.729179  [19200/60000]
# loss: 0.626007  [25600/60000]
# loss: 0.626533  [32000/60000]
# loss: 0.676804  [38400/60000]
# loss: 0.716444  [44800/60000]
# loss: 0.694577  [51200/60000]
# loss: 0.647209  [57600/60000]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.643568
#
# Epoch 19
# -------------------------------
# loss: 0.572537  [    0/60000]
# loss: 0.685010  [ 6400/60000]
# loss: 0.478389  [12800/60000]
# loss: 0.717676  [19200/60000]
# loss: 0.616679  [25600/60000]
# loss: 0.617351  [32000/60000]
# loss: 0.661874  [38400/60000]
# loss: 0.708307  [44800/60000]
# loss: 0.684798  [51200/60000]
# loss: 0.635329  [57600/60000]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.631492
#
# Epoch 20
# -------------------------------
# loss: 0.556151  [    0/60000]
# loss: 0.669440  [ 6400/60000]
# loss: 0.465800  [12800/60000]
# loss: 0.706817  [19200/60000]
# loss: 0.608158  [25600/60000]
# loss: 0.608991  [32000/60000]
# loss: 0.647953  [38400/60000]
# loss: 0.701244  [44800/60000]
# loss: 0.676169  [51200/60000]
# loss: 0.624220  [57600/60000]
# Test Error:
#  Accuracy: 78.5%, Avg loss: 0.620343
#
# Epoch 21
# -------------------------------
# loss: 0.541246  [    0/60000]
# loss: 0.655041  [ 6400/60000]
# loss: 0.454276  [12800/60000]
# loss: 0.696597  [19200/60000]
# loss: 0.600335  [25600/60000]
# loss: 0.601376  [32000/60000]
# loss: 0.635014  [38400/60000]
# loss: 0.695235  [44800/60000]
# loss: 0.668614  [51200/60000]
# loss: 0.613632  [57600/60000]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.610053
#
# Epoch 22
# -------------------------------
# loss: 0.527604  [    0/60000]
# loss: 0.641824  [ 6400/60000]
# loss: 0.443724  [12800/60000]
# loss: 0.686961  [19200/60000]
# loss: 0.593163  [25600/60000]
# loss: 0.594335  [32000/60000]
# loss: 0.623014  [38400/60000]
# loss: 0.690284  [44800/60000]
# loss: 0.662021  [51200/60000]
# loss: 0.603494  [57600/60000]
# Test Error:
#  Accuracy: 79.3%, Avg loss: 0.600563
#
# Epoch 23
# -------------------------------
# loss: 0.515068  [    0/60000]
# loss: 0.629684  [ 6400/60000]
# loss: 0.434023  [12800/60000]
# loss: 0.677888  [19200/60000]
# loss: 0.586369  [25600/60000]
# loss: 0.587832  [32000/60000]
# loss: 0.611922  [38400/60000]
# loss: 0.686316  [44800/60000]
# loss: 0.656270  [51200/60000]
# loss: 0.593729  [57600/60000]
# Test Error:
#  Accuracy: 79.5%, Avg loss: 0.591815
#
# Epoch 24
# -------------------------------
# loss: 0.503498  [    0/60000]
# loss: 0.618553  [ 6400/60000]
# loss: 0.425068  [12800/60000]
# loss: 0.669276  [19200/60000]
# loss: 0.579875  [25600/60000]
# loss: 0.581709  [32000/60000]
# loss: 0.601586  [38400/60000]
# loss: 0.683231  [44800/60000]
# loss: 0.651244  [51200/60000]
# loss: 0.584260  [57600/60000]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.583750
#
# Epoch 25
# -------------------------------
# loss: 0.492806  [    0/60000]
# loss: 0.608334  [ 6400/60000]
# loss: 0.416820  [12800/60000]
# loss: 0.661154  [19200/60000]
# loss: 0.573629  [25600/60000]
# loss: 0.575965  [32000/60000]
# loss: 0.591953  [38400/60000]
# loss: 0.680884  [44800/60000]
# loss: 0.646898  [51200/60000]
# loss: 0.575108  [57600/60000]
# Test Error:
#  Accuracy: 80.1%, Avg loss: 0.576316
#
# Epoch 26
# -------------------------------
# loss: 0.482929  [    0/60000]
# loss: 0.598950  [ 6400/60000]
# loss: 0.409213  [12800/60000]
# loss: 0.653454  [19200/60000]
# loss: 0.567535  [25600/60000]
# loss: 0.570491  [32000/60000]
# loss: 0.583016  [38400/60000]
# loss: 0.679156  [44800/60000]
# loss: 0.643117  [51200/60000]
# loss: 0.566256  [57600/60000]
# Test Error:
#  Accuracy: 80.3%, Avg loss: 0.569454
#
# Epoch 27
# -------------------------------
# loss: 0.473718  [    0/60000]
# loss: 0.590338  [ 6400/60000]
# loss: 0.402075  [12800/60000]
# loss: 0.646186  [19200/60000]
# loss: 0.561542  [25600/60000]
# loss: 0.565200  [32000/60000]
# loss: 0.574712  [38400/60000]
# loss: 0.677969  [44800/60000]
# loss: 0.639737  [51200/60000]
# loss: 0.557666  [57600/60000]
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.563104
#
# Epoch 28
# -------------------------------
# loss: 0.465156  [    0/60000]
# loss: 0.582419  [ 6400/60000]
# loss: 0.395428  [12800/60000]
# loss: 0.639285  [19200/60000]
# loss: 0.555711  [25600/60000]
# loss: 0.560082  [32000/60000]
# loss: 0.567059  [38400/60000]
# loss: 0.677240  [44800/60000]
# loss: 0.636712  [51200/60000]
# loss: 0.549398  [57600/60000]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.557213
#
# Epoch 29
# -------------------------------
# loss: 0.457059  [    0/60000]
# loss: 0.575106  [ 6400/60000]
# loss: 0.389260  [12800/60000]
# loss: 0.632811  [19200/60000]
# loss: 0.549964  [25600/60000]
# loss: 0.555063  [32000/60000]
# loss: 0.560012  [38400/60000]
# loss: 0.676913  [44800/60000]
# loss: 0.633938  [51200/60000]
# loss: 0.541492  [57600/60000]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.551747
#
# Epoch 30
# -------------------------------
# loss: 0.449447  [    0/60000]
# loss: 0.568361  [ 6400/60000]
# loss: 0.383521  [12800/60000]
# loss: 0.626604  [19200/60000]
# loss: 0.544337  [25600/60000]
# loss: 0.550143  [32000/60000]
# loss: 0.553457  [38400/60000]
# loss: 0.676888  [44800/60000]
# loss: 0.631465  [51200/60000]
# loss: 0.533856  [57600/60000]
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.546666
#
# Epoch 31
# -------------------------------
# loss: 0.442234  [    0/60000]
# loss: 0.562180  [ 6400/60000]
# loss: 0.378135  [12800/60000]
# loss: 0.620564  [19200/60000]
# loss: 0.538812  [25600/60000]
# loss: 0.545286  [32000/60000]
# loss: 0.547344  [38400/60000]
# loss: 0.677140  [44800/60000]
# loss: 0.629096  [51200/60000]
# loss: 0.526447  [57600/60000]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.541942
#
# Epoch 32
# -------------------------------
# loss: 0.435447  [    0/60000]
# loss: 0.556516  [ 6400/60000]
# loss: 0.373098  [12800/60000]
# loss: 0.614918  [19200/60000]
# loss: 0.533279  [25600/60000]
# loss: 0.540543  [32000/60000]
# loss: 0.541652  [38400/60000]
# loss: 0.677473  [44800/60000]
# loss: 0.626913  [51200/60000]
# loss: 0.519236  [57600/60000]
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.537537
#
# Epoch 33
# -------------------------------
# loss: 0.429048  [    0/60000]
# loss: 0.551272  [ 6400/60000]
# loss: 0.368387  [12800/60000]
# loss: 0.609442  [19200/60000]
# loss: 0.527886  [25600/60000]
# loss: 0.535890  [32000/60000]
# loss: 0.536365  [38400/60000]
# loss: 0.677793  [44800/60000]
# loss: 0.624810  [51200/60000]
# loss: 0.512330  [57600/60000]
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.533424
#
# Epoch 34
# -------------------------------
# loss: 0.422895  [    0/60000]
# loss: 0.546446  [ 6400/60000]
# loss: 0.363955  [12800/60000]
# loss: 0.604217  [19200/60000]
# loss: 0.522618  [25600/60000]
# loss: 0.531380  [32000/60000]
# loss: 0.531397  [38400/60000]
# loss: 0.678029  [44800/60000]
# loss: 0.622762  [51200/60000]
# loss: 0.505671  [57600/60000]
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.529576
#
# Epoch 35
# -------------------------------
# loss: 0.416951  [    0/60000]
# loss: 0.542030  [ 6400/60000]
# loss: 0.359810  [12800/60000]
# loss: 0.599157  [19200/60000]
# loss: 0.517434  [25600/60000]
# loss: 0.526951  [32000/60000]
# loss: 0.526696  [38400/60000]
# loss: 0.678291  [44800/60000]
# loss: 0.620742  [51200/60000]
# loss: 0.499270  [57600/60000]
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.525969
#
# Epoch 36
# -------------------------------
# loss: 0.411358  [    0/60000]
# loss: 0.537934  [ 6400/60000]
# loss: 0.355920  [12800/60000]
# loss: 0.594321  [19200/60000]
# loss: 0.512408  [25600/60000]
# loss: 0.522514  [32000/60000]
# loss: 0.522273  [38400/60000]
# loss: 0.678483  [44800/60000]
# loss: 0.618810  [51200/60000]
# loss: 0.493175  [57600/60000]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.522576
#
# Epoch 37
# -------------------------------
# loss: 0.406018  [    0/60000]
# loss: 0.534122  [ 6400/60000]
# loss: 0.352257  [12800/60000]
# loss: 0.589647  [19200/60000]
# loss: 0.507498  [25600/60000]
# loss: 0.518176  [32000/60000]
# loss: 0.518019  [38400/60000]
# loss: 0.678586  [44800/60000]
# loss: 0.616883  [51200/60000]
# loss: 0.487356  [57600/60000]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.519377
#
# Epoch 38
# -------------------------------
# loss: 0.400878  [    0/60000]
# loss: 0.530590  [ 6400/60000]
# loss: 0.348786  [12800/60000]
# loss: 0.585160  [19200/60000]
# loss: 0.502671  [25600/60000]
# loss: 0.513953  [32000/60000]
# loss: 0.513961  [38400/60000]
# loss: 0.678581  [44800/60000]
# loss: 0.614987  [51200/60000]
# loss: 0.481760  [57600/60000]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.516354
#
# Epoch 39
# -------------------------------
# loss: 0.395954  [    0/60000]
# loss: 0.527271  [ 6400/60000]
# loss: 0.345467  [12800/60000]
# loss: 0.580802  [19200/60000]
# loss: 0.498040  [25600/60000]
# loss: 0.509839  [32000/60000]
# loss: 0.510114  [38400/60000]
# loss: 0.678478  [44800/60000]
# loss: 0.613092  [51200/60000]
# loss: 0.476436  [57600/60000]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.513484
#
# Epoch 40
# -------------------------------
# loss: 0.391259  [    0/60000]
# loss: 0.524187  [ 6400/60000]
# loss: 0.342315  [12800/60000]
# loss: 0.576577  [19200/60000]
# loss: 0.493533  [25600/60000]
# loss: 0.505834  [32000/60000]
# loss: 0.506474  [38400/60000]
# loss: 0.678251  [44800/60000]
# loss: 0.611262  [51200/60000]
# loss: 0.471428  [57600/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.510759
#
# Epoch 41
# -------------------------------
# loss: 0.386729  [    0/60000]
# loss: 0.521290  [ 6400/60000]
# loss: 0.339274  [12800/60000]
# loss: 0.572547  [19200/60000]
# loss: 0.489141  [25600/60000]
# loss: 0.501948  [32000/60000]
# loss: 0.503009  [38400/60000]
# loss: 0.677891  [44800/60000]
# loss: 0.609459  [51200/60000]
# loss: 0.466657  [57600/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.508168
#
# Epoch 42
# -------------------------------
# loss: 0.382344  [    0/60000]
# loss: 0.518526  [ 6400/60000]
# loss: 0.336378  [12800/60000]
# loss: 0.568668  [19200/60000]
# loss: 0.484833  [25600/60000]
# loss: 0.498237  [32000/60000]
# loss: 0.499705  [38400/60000]
# loss: 0.677358  [44800/60000]
# loss: 0.607698  [51200/60000]
# loss: 0.462072  [57600/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.505696
#
# Epoch 43
# -------------------------------
# loss: 0.378123  [    0/60000]
# loss: 0.515923  [ 6400/60000]
# loss: 0.333607  [12800/60000]
# loss: 0.564934  [19200/60000]
# loss: 0.480741  [25600/60000]
# loss: 0.494588  [32000/60000]
# loss: 0.496534  [38400/60000]
# loss: 0.676738  [44800/60000]
# loss: 0.605945  [51200/60000]
# loss: 0.457714  [57600/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.503333
#
# Epoch 44
# -------------------------------
# loss: 0.374019  [    0/60000]
# loss: 0.513439  [ 6400/60000]
# loss: 0.330960  [12800/60000]
# loss: 0.561364  [19200/60000]
# loss: 0.476805  [25600/60000]
# loss: 0.491067  [32000/60000]
# loss: 0.493503  [38400/60000]
# loss: 0.676029  [44800/60000]
# loss: 0.604173  [51200/60000]
# loss: 0.453549  [57600/60000]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.501059
#
# Epoch 45
# -------------------------------
# loss: 0.370085  [    0/60000]
# loss: 0.511106  [ 6400/60000]
# loss: 0.328417  [12800/60000]
# loss: 0.557917  [19200/60000]
# loss: 0.472970  [25600/60000]
# loss: 0.487621  [32000/60000]
# loss: 0.490613  [38400/60000]
# loss: 0.675232  [44800/60000]
# loss: 0.602251  [51200/60000]
# loss: 0.449572  [57600/60000]
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.498872
#
# Epoch 46
# -------------------------------
# loss: 0.366276  [    0/60000]
# loss: 0.508872  [ 6400/60000]
# loss: 0.325961  [12800/60000]
# loss: 0.554566  [19200/60000]
# loss: 0.469274  [25600/60000]
# loss: 0.484172  [32000/60000]
# loss: 0.487830  [38400/60000]
# loss: 0.674262  [44800/60000]
# loss: 0.600139  [51200/60000]
# loss: 0.445848  [57600/60000]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.496760
#
# Epoch 47
# -------------------------------
# loss: 0.362552  [    0/60000]
# loss: 0.506735  [ 6400/60000]
# loss: 0.323611  [12800/60000]
# loss: 0.551352  [19200/60000]
# loss: 0.465695  [25600/60000]
# loss: 0.480943  [32000/60000]
# loss: 0.485160  [38400/60000]
# loss: 0.673003  [44800/60000]
# loss: 0.598137  [51200/60000]
# loss: 0.442399  [57600/60000]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.494720
#
# Epoch 48
# -------------------------------
# loss: 0.359007  [    0/60000]
# loss: 0.504705  [ 6400/60000]
# loss: 0.321270  [12800/60000]
# loss: 0.548257  [19200/60000]
# loss: 0.462248  [25600/60000]
# loss: 0.477805  [32000/60000]
# loss: 0.482621  [38400/60000]
# loss: 0.671561  [44800/60000]
# loss: 0.596247  [51200/60000]
# loss: 0.439242  [57600/60000]
# Test Error:
#  Accuracy: 82.6%, Avg loss: 0.492742
#
# Epoch 49
# -------------------------------
# loss: 0.355578  [    0/60000]
# loss: 0.502769  [ 6400/60000]
# loss: 0.319021  [12800/60000]
# loss: 0.545224  [19200/60000]
# loss: 0.458990  [25600/60000]
# loss: 0.474779  [32000/60000]
# loss: 0.480060  [38400/60000]
# loss: 0.670026  [44800/60000]
# loss: 0.594371  [51200/60000]
# loss: 0.436293  [57600/60000]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.490815
#
# Epoch 50
# -------------------------------
# loss: 0.352291  [    0/60000]
# loss: 0.500811  [ 6400/60000]
# loss: 0.316844  [12800/60000]
# loss: 0.542431  [19200/60000]
# loss: 0.455767  [25600/60000]
# loss: 0.471906  [32000/60000]
# loss: 0.477647  [38400/60000]
# loss: 0.668459  [44800/60000]
# loss: 0.592507  [51200/60000]
# loss: 0.433511  [57600/60000]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.488975
#
# Done!

# %%
model = NeuralNetwork()
optimizer_rms = RMSprop(model.parameters(), lr=LEARNING_RATE, alpha=0.9)
print('Training with RMSprop optimizer')
test_loss_rms = run_training(EPOCHS, train_dataloader, test_dataloader, model, nn.CrossEntropyLoss(), optimizer_rms)
# Out:
# Training with RMSprop optimizer
# Epoch 1
# -------------------------------
# loss: 2.303881  [    0/60000]
# loss: 0.587110  [ 6400/60000]
# loss: 0.458827  [12800/60000]
# loss: 0.496801  [19200/60000]
# loss: 0.479458  [25600/60000]
# loss: 0.415252  [32000/60000]
# loss: 0.395175  [38400/60000]
# loss: 0.514746  [44800/60000]
# loss: 0.534121  [51200/60000]
# loss: 0.471741  [57600/60000]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.458552
#
# Epoch 2
# -------------------------------
# loss: 0.276878  [    0/60000]
# loss: 0.326664  [ 6400/60000]
# loss: 0.300769  [12800/60000]
# loss: 0.335456  [19200/60000]
# loss: 0.329315  [25600/60000]
# loss: 0.394687  [32000/60000]
# loss: 0.304999  [38400/60000]
# loss: 0.415182  [44800/60000]
# loss: 0.455108  [51200/60000]
# loss: 0.344987  [57600/60000]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.461019
#
# Epoch 3
# -------------------------------
# loss: 0.234554  [    0/60000]
# loss: 0.332579  [ 6400/60000]
# loss: 0.227552  [12800/60000]
# loss: 0.305283  [19200/60000]
# loss: 0.331544  [25600/60000]
# loss: 0.398127  [32000/60000]
# loss: 0.267274  [38400/60000]
# loss: 0.415459  [44800/60000]
# loss: 0.417841  [51200/60000]
# loss: 0.351570  [57600/60000]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.432617
#
# Epoch 4
# -------------------------------
# loss: 0.207967  [    0/60000]
# loss: 0.332855  [ 6400/60000]
# loss: 0.230629  [12800/60000]
# loss: 0.271171  [19200/60000]
# loss: 0.357781  [25600/60000]
# loss: 0.353660  [32000/60000]
# loss: 0.259057  [38400/60000]
# loss: 0.435254  [44800/60000]
# loss: 0.440935  [51200/60000]
# loss: 0.409431  [57600/60000]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.439755
#
# Epoch 5
# -------------------------------
# loss: 0.224395  [    0/60000]
# loss: 0.329680  [ 6400/60000]
# loss: 0.218214  [12800/60000]
# loss: 0.259056  [19200/60000]
# loss: 0.297076  [25600/60000]
# loss: 0.408246  [32000/60000]
# loss: 0.234123  [38400/60000]
# loss: 0.401332  [44800/60000]
# loss: 0.406389  [51200/60000]
# loss: 0.417086  [57600/60000]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.432643
#
# Epoch 6
# -------------------------------
# loss: 0.178008  [    0/60000]
# loss: 0.351875  [ 6400/60000]
# loss: 0.210343  [12800/60000]
# loss: 0.244252  [19200/60000]
# loss: 0.351876  [25600/60000]
# loss: 0.397455  [32000/60000]
# loss: 0.218561  [38400/60000]
# loss: 0.352887  [44800/60000]
# loss: 0.385843  [51200/60000]
# loss: 0.340371  [57600/60000]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.483614
#
# Epoch 7
# -------------------------------
# loss: 0.219239  [    0/60000]
# loss: 0.255380  [ 6400/60000]
# loss: 0.208250  [12800/60000]
# loss: 0.221599  [19200/60000]
# loss: 0.371117  [25600/60000]
# loss: 0.438131  [32000/60000]
# loss: 0.235432  [38400/60000]
# loss: 0.344330  [44800/60000]
# loss: 0.460067  [51200/60000]
# loss: 0.346327  [57600/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.484361
#
# Epoch 8
# -------------------------------
# loss: 0.207975  [    0/60000]
# loss: 0.333500  [ 6400/60000]
# loss: 0.249138  [12800/60000]
# loss: 0.248207  [19200/60000]
# loss: 0.274359  [25600/60000]
# loss: 0.407289  [32000/60000]
# loss: 0.245972  [38400/60000]
# loss: 0.330492  [44800/60000]
# loss: 0.360841  [51200/60000]
# loss: 0.309392  [57600/60000]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.506466
#
# Epoch 9
# -------------------------------
# loss: 0.179798  [    0/60000]
# loss: 0.325662  [ 6400/60000]
# loss: 0.224289  [12800/60000]
# loss: 0.211293  [19200/60000]
# loss: 0.492094  [25600/60000]
# loss: 0.374147  [32000/60000]
# loss: 0.243083  [38400/60000]
# loss: 0.294193  [44800/60000]
# loss: 0.391174  [51200/60000]
# loss: 0.338999  [57600/60000]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.558798
#
# Epoch 10
# -------------------------------
# loss: 0.206783  [    0/60000]
# loss: 0.236635  [ 6400/60000]
# loss: 0.200050  [12800/60000]
# loss: 0.226587  [19200/60000]
# loss: 0.361272  [25600/60000]
# loss: 0.485092  [32000/60000]
# loss: 0.274965  [38400/60000]
# loss: 0.265357  [44800/60000]
# loss: 0.283731  [51200/60000]
# loss: 0.272691  [57600/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.518554
#
# Epoch 11
# -------------------------------
# loss: 0.170590  [    0/60000]
# loss: 0.414586  [ 6400/60000]
# loss: 0.199807  [12800/60000]
# loss: 0.217907  [19200/60000]
# loss: 0.242248  [25600/60000]
# loss: 0.348994  [32000/60000]
# loss: 0.186832  [38400/60000]
# loss: 0.289160  [44800/60000]
# loss: 0.389460  [51200/60000]
# loss: 0.231027  [57600/60000]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.531358
#
# Epoch 12
# -------------------------------
# loss: 0.245357  [    0/60000]
# loss: 0.253657  [ 6400/60000]
# loss: 0.210541  [12800/60000]
# loss: 0.276043  [19200/60000]
# loss: 0.300467  [25600/60000]
# loss: 0.263832  [32000/60000]
# loss: 0.238700  [38400/60000]
# loss: 0.284816  [44800/60000]
# loss: 0.326489  [51200/60000]
# loss: 0.245837  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.554036
#
# Epoch 13
# -------------------------------
# loss: 0.171653  [    0/60000]
# loss: 0.221293  [ 6400/60000]
# loss: 0.200339  [12800/60000]
# loss: 0.259232  [19200/60000]
# loss: 0.310141  [25600/60000]
# loss: 0.331016  [32000/60000]
# loss: 0.206206  [38400/60000]
# loss: 0.290726  [44800/60000]
# loss: 0.288997  [51200/60000]
# loss: 0.302602  [57600/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.554066
#
# Epoch 14
# -------------------------------
# loss: 0.164920  [    0/60000]
# loss: 0.746174  [ 6400/60000]
# loss: 0.188287  [12800/60000]
# loss: 0.222026  [19200/60000]
# loss: 0.414164  [25600/60000]
# loss: 0.382940  [32000/60000]
# loss: 0.179249  [38400/60000]
# loss: 0.205015  [44800/60000]
# loss: 0.250036  [51200/60000]
# loss: 0.229080  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.559466
#
# Epoch 15
# -------------------------------
# loss: 0.172204  [    0/60000]
# loss: 0.278084  [ 6400/60000]
# loss: 0.179257  [12800/60000]
# loss: 0.230573  [19200/60000]
# loss: 0.407599  [25600/60000]
# loss: 0.276077  [32000/60000]
# loss: 0.181896  [38400/60000]
# loss: 0.350111  [44800/60000]
# loss: 0.398403  [51200/60000]
# loss: 0.212236  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.624395
#
# Epoch 16
# -------------------------------
# loss: 0.152667  [    0/60000]
# loss: 0.237841  [ 6400/60000]
# loss: 0.173559  [12800/60000]
# loss: 0.229009  [19200/60000]
# loss: 0.302670  [25600/60000]
# loss: 0.217683  [32000/60000]
# loss: 0.202798  [38400/60000]
# loss: 0.214810  [44800/60000]
# loss: 0.302282  [51200/60000]
# loss: 0.279584  [57600/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.583874
#
# Epoch 17
# -------------------------------
# loss: 0.232682  [    0/60000]
# loss: 0.276238  [ 6400/60000]
# loss: 0.236033  [12800/60000]
# loss: 0.252932  [19200/60000]
# loss: 0.414617  [25600/60000]
# loss: 0.244005  [32000/60000]
# loss: 0.193269  [38400/60000]
# loss: 0.416167  [44800/60000]
# loss: 0.338211  [51200/60000]
# loss: 0.282917  [57600/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.616377
#
# Epoch 18
# -------------------------------
# loss: 0.236244  [    0/60000]
# loss: 0.188003  [ 6400/60000]
# loss: 0.242902  [12800/60000]
# loss: 0.249441  [19200/60000]
# loss: 0.200552  [25600/60000]
# loss: 0.228301  [32000/60000]
# loss: 0.186210  [38400/60000]
# loss: 0.295182  [44800/60000]
# loss: 0.418433  [51200/60000]
# loss: 0.205703  [57600/60000]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.715042
#
# Epoch 19
# -------------------------------
# loss: 0.215377  [    0/60000]
# loss: 0.180352  [ 6400/60000]
# loss: 0.190741  [12800/60000]
# loss: 0.221768  [19200/60000]
# loss: 0.440584  [25600/60000]
# loss: 0.451625  [32000/60000]
# loss: 0.268298  [38400/60000]
# loss: 0.245041  [44800/60000]
# loss: 0.370555  [51200/60000]
# loss: 0.190402  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.683723
#
# Epoch 20
# -------------------------------
# loss: 0.131345  [    0/60000]
# loss: 0.308726  [ 6400/60000]
# loss: 0.165923  [12800/60000]
# loss: 0.192766  [19200/60000]
# loss: 0.373228  [25600/60000]
# loss: 0.208384  [32000/60000]
# loss: 0.175582  [38400/60000]
# loss: 0.298508  [44800/60000]
# loss: 0.327236  [51200/60000]
# loss: 0.254622  [57600/60000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.718352
#
# Epoch 21
# -------------------------------
# loss: 0.157118  [    0/60000]
# loss: 0.264733  [ 6400/60000]
# loss: 0.167151  [12800/60000]
# loss: 0.162707  [19200/60000]
# loss: 0.317244  [25600/60000]
# loss: 0.191314  [32000/60000]
# loss: 0.494147  [38400/60000]
# loss: 0.214593  [44800/60000]
# loss: 0.218815  [51200/60000]
# loss: 0.249652  [57600/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.681784
#
# Epoch 22
# -------------------------------
# loss: 0.182585  [    0/60000]
# loss: 0.482989  [ 6400/60000]
# loss: 0.174540  [12800/60000]
# loss: 0.222080  [19200/60000]
# loss: 0.298618  [25600/60000]
# loss: 0.233244  [32000/60000]
# loss: 0.159449  [38400/60000]
# loss: 0.237900  [44800/60000]
# loss: 0.302430  [51200/60000]
# loss: 0.184604  [57600/60000]
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.714855
#
# Epoch 23
# -------------------------------
# loss: 0.195349  [    0/60000]
# loss: 0.205519  [ 6400/60000]
# loss: 0.355910  [12800/60000]
# loss: 0.175533  [19200/60000]
# loss: 0.481736  [25600/60000]
# loss: 0.197278  [32000/60000]
# loss: 0.134929  [38400/60000]
# loss: 0.266036  [44800/60000]
# loss: 0.256588  [51200/60000]
# loss: 0.198479  [57600/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.710612
#
# Epoch 24
# -------------------------------
# loss: 0.116597  [    0/60000]
# loss: 0.202744  [ 6400/60000]
# loss: 0.168138  [12800/60000]
# loss: 0.168468  [19200/60000]
# loss: 0.407427  [25600/60000]
# loss: 0.150038  [32000/60000]
# loss: 0.176411  [38400/60000]
# loss: 0.243647  [44800/60000]
# loss: 0.221475  [51200/60000]
# loss: 0.193728  [57600/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.704499
#
# Epoch 25
# -------------------------------
# loss: 0.137992  [    0/60000]
# loss: 0.190130  [ 6400/60000]
# loss: 0.145315  [12800/60000]
# loss: 0.232944  [19200/60000]
# loss: 0.229011  [25600/60000]
# loss: 0.299048  [32000/60000]
# loss: 0.149277  [38400/60000]
# loss: 0.336989  [44800/60000]
# loss: 0.301836  [51200/60000]
# loss: 0.177388  [57600/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.769241
#
# Epoch 26
# -------------------------------
# loss: 0.153356  [    0/60000]
# loss: 0.217418  [ 6400/60000]
# loss: 0.151481  [12800/60000]
# loss: 0.202105  [19200/60000]
# loss: 0.295353  [25600/60000]
# loss: 0.197953  [32000/60000]
# loss: 0.167995  [38400/60000]
# loss: 0.195491  [44800/60000]
# loss: 0.492349  [51200/60000]
# loss: 0.242926  [57600/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.733490
#
# Epoch 27
# -------------------------------
# loss: 0.152425  [    0/60000]
# loss: 0.158253  [ 6400/60000]
# loss: 0.151107  [12800/60000]
# loss: 0.181834  [19200/60000]
# loss: 0.383745  [25600/60000]
# loss: 0.179970  [32000/60000]
# loss: 0.159875  [38400/60000]
# loss: 0.320112  [44800/60000]
# loss: 0.249291  [51200/60000]
# loss: 0.148242  [57600/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.765247
#
# Epoch 28
# -------------------------------
# loss: 0.194415  [    0/60000]
# loss: 0.226199  [ 6400/60000]
# loss: 0.399458  [12800/60000]
# loss: 0.185072  [19200/60000]
# loss: 0.362551  [25600/60000]
# loss: 0.186150  [32000/60000]
# loss: 0.132559  [38400/60000]
# loss: 0.363049  [44800/60000]
# loss: 0.252438  [51200/60000]
# loss: 0.100407  [57600/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.932383
#
# Epoch 29
# -------------------------------
# loss: 0.158377  [    0/60000]
# loss: 0.233540  [ 6400/60000]
# loss: 0.270273  [12800/60000]
# loss: 0.174895  [19200/60000]
# loss: 0.328360  [25600/60000]
# loss: 0.227654  [32000/60000]
# loss: 0.158545  [38400/60000]
# loss: 0.225620  [44800/60000]
# loss: 0.210364  [51200/60000]
# loss: 0.164061  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.844324
#
# Epoch 30
# -------------------------------
# loss: 0.298752  [    0/60000]
# loss: 0.229857  [ 6400/60000]
# loss: 0.214338  [12800/60000]
# loss: 0.126266  [19200/60000]
# loss: 0.215412  [25600/60000]
# loss: 0.175110  [32000/60000]
# loss: 0.129921  [38400/60000]
# loss: 0.223393  [44800/60000]
# loss: 0.359248  [51200/60000]
# loss: 0.193123  [57600/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.808178
#
# Epoch 31
# -------------------------------
# loss: 0.204838  [    0/60000]
# loss: 0.141650  [ 6400/60000]
# loss: 0.269336  [12800/60000]
# loss: 0.174894  [19200/60000]
# loss: 0.249139  [25600/60000]
# loss: 0.215414  [32000/60000]
# loss: 0.145502  [38400/60000]
# loss: 0.191530  [44800/60000]
# loss: 0.318489  [51200/60000]
# loss: 0.182628  [57600/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.863641
#
# Epoch 32
# -------------------------------
# loss: 0.108843  [    0/60000]
# loss: 0.133347  [ 6400/60000]
# loss: 0.094356  [12800/60000]
# loss: 0.228370  [19200/60000]
# loss: 0.222688  [25600/60000]
# loss: 0.177736  [32000/60000]
# loss: 0.131423  [38400/60000]
# loss: 0.252144  [44800/60000]
# loss: 0.249023  [51200/60000]
# loss: 0.218152  [57600/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.905109
#
# Epoch 33
# -------------------------------
# loss: 0.111301  [    0/60000]
# loss: 0.175516  [ 6400/60000]
# loss: 0.169793  [12800/60000]
# loss: 0.218361  [19200/60000]
# loss: 0.392810  [25600/60000]
# loss: 0.461969  [32000/60000]
# loss: 0.167125  [38400/60000]
# loss: 0.130774  [44800/60000]
# loss: 0.287515  [51200/60000]
# loss: 0.227144  [57600/60000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 1.058929
#
# Epoch 34
# -------------------------------
# loss: 0.192948  [    0/60000]
# loss: 0.149731  [ 6400/60000]
# loss: 0.187678  [12800/60000]
# loss: 0.158849  [19200/60000]
# loss: 0.296092  [25600/60000]
# loss: 0.186989  [32000/60000]
# loss: 0.144521  [38400/60000]
# loss: 0.201456  [44800/60000]
# loss: 0.212840  [51200/60000]
# loss: 0.168886  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.864903
#
# Epoch 35
# -------------------------------
# loss: 0.116906  [    0/60000]
# loss: 0.149454  [ 6400/60000]
# loss: 0.221321  [12800/60000]
# loss: 0.146197  [19200/60000]
# loss: 0.239149  [25600/60000]
# loss: 0.169596  [32000/60000]
# loss: 0.116029  [38400/60000]
# loss: 0.302527  [44800/60000]
# loss: 0.145865  [51200/60000]
# loss: 0.122717  [57600/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.979205
#
# Epoch 36
# -------------------------------
# loss: 0.080154  [    0/60000]
# loss: 0.144041  [ 6400/60000]
# loss: 0.160317  [12800/60000]
# loss: 0.118399  [19200/60000]
# loss: 0.372971  [25600/60000]
# loss: 0.181386  [32000/60000]
# loss: 0.115226  [38400/60000]
# loss: 0.307883  [44800/60000]
# loss: 0.253663  [51200/60000]
# loss: 0.117788  [57600/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 1.076129
#
# Epoch 37
# -------------------------------
# loss: 0.156861  [    0/60000]
# loss: 0.150966  [ 6400/60000]
# loss: 0.165885  [12800/60000]
# loss: 0.127458  [19200/60000]
# loss: 0.553591  [25600/60000]
# loss: 0.562447  [32000/60000]
# loss: 0.298041  [38400/60000]
# loss: 0.240507  [44800/60000]
# loss: 0.146874  [51200/60000]
# loss: 0.212537  [57600/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.969140
#
# Epoch 38
# -------------------------------
# loss: 0.116601  [    0/60000]
# loss: 0.124308  [ 6400/60000]
# loss: 0.248400  [12800/60000]
# loss: 0.110395  [19200/60000]
# loss: 0.355236  [25600/60000]
# loss: 0.359113  [32000/60000]
# loss: 0.153219  [38400/60000]
# loss: 0.342114  [44800/60000]
# loss: 0.255588  [51200/60000]
# loss: 0.195908  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.970623
#
# Epoch 39
# -------------------------------
# loss: 0.147980  [    0/60000]
# loss: 0.188176  [ 6400/60000]
# loss: 0.143838  [12800/60000]
# loss: 0.156562  [19200/60000]
# loss: 2.424492  [25600/60000]
# loss: 0.187189  [32000/60000]
# loss: 0.155771  [38400/60000]
# loss: 0.153456  [44800/60000]
# loss: 0.181021  [51200/60000]
# loss: 0.182252  [57600/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 1.141752
#
# Epoch 40
# -------------------------------
# loss: 0.190837  [    0/60000]
# loss: 0.143149  [ 6400/60000]
# loss: 0.195462  [12800/60000]
# loss: 0.160669  [19200/60000]
# loss: 0.366158  [25600/60000]
# loss: 0.165428  [32000/60000]
# loss: 0.133846  [38400/60000]
# loss: 0.285472  [44800/60000]
# loss: 0.174067  [51200/60000]
# loss: 0.192335  [57600/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 1.169762
#
# Epoch 41
# -------------------------------
# loss: 0.108911  [    0/60000]
# loss: 0.126790  [ 6400/60000]
# loss: 0.211551  [12800/60000]
# loss: 0.233585  [19200/60000]
# loss: 0.281625  [25600/60000]
# loss: 0.167678  [32000/60000]
# loss: 0.110174  [38400/60000]
# loss: 0.199921  [44800/60000]
# loss: 0.199801  [51200/60000]
# loss: 0.118085  [57600/60000]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 1.056448
#
# Epoch 42
# -------------------------------
# loss: 0.152393  [    0/60000]
# loss: 0.675725  [ 6400/60000]
# loss: 0.263333  [12800/60000]
# loss: 0.124959  [19200/60000]
# loss: 0.283639  [25600/60000]
# loss: 1.077682  [32000/60000]
# loss: 0.135849  [38400/60000]
# loss: 0.260000  [44800/60000]
# loss: 0.162435  [51200/60000]
# loss: 0.147019  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 1.073843
#
# Epoch 43
# -------------------------------
# loss: 0.125151  [    0/60000]
# loss: 0.161937  [ 6400/60000]
# loss: 0.150275  [12800/60000]
# loss: 0.124917  [19200/60000]
# loss: 0.247789  [25600/60000]
# loss: 0.193985  [32000/60000]
# loss: 0.100191  [38400/60000]
# loss: 0.111473  [44800/60000]
# loss: 0.201583  [51200/60000]
# loss: 0.130428  [57600/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 1.148166
#
# Epoch 44
# -------------------------------
# loss: 0.111021  [    0/60000]
# loss: 0.113316  [ 6400/60000]
# loss: 0.104310  [12800/60000]
# loss: 0.128085  [19200/60000]
# loss: 0.516916  [25600/60000]
# loss: 0.136363  [32000/60000]
# loss: 0.124439  [38400/60000]
# loss: 0.166692  [44800/60000]
# loss: 0.202426  [51200/60000]
# loss: 0.141387  [57600/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 1.147392
#
# Epoch 45
# -------------------------------
# loss: 0.115495  [    0/60000]
# loss: 0.127120  [ 6400/60000]
# loss: 0.158464  [12800/60000]
# loss: 0.089603  [19200/60000]
# loss: 0.640970  [25600/60000]
# loss: 0.160198  [32000/60000]
# loss: 0.129094  [38400/60000]
# loss: 0.239654  [44800/60000]
# loss: 0.193393  [51200/60000]
# loss: 0.087709  [57600/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 1.269513
#
# Epoch 46
# -------------------------------
# loss: 0.077673  [    0/60000]
# loss: 0.168257  [ 6400/60000]
# loss: 0.235937  [12800/60000]
# loss: 0.139721  [19200/60000]
# loss: 0.325316  [25600/60000]
# loss: 0.167783  [32000/60000]
# loss: 0.121167  [38400/60000]
# loss: 0.170005  [44800/60000]
# loss: 0.173898  [51200/60000]
# loss: 0.158200  [57600/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 1.283529
#
# Epoch 47
# -------------------------------
# loss: 0.106738  [    0/60000]
# loss: 0.144960  [ 6400/60000]
# loss: 0.174532  [12800/60000]
# loss: 0.119205  [19200/60000]
# loss: 0.295878  [25600/60000]
# loss: 0.302346  [32000/60000]
# loss: 0.151042  [38400/60000]
# loss: 0.264208  [44800/60000]
# loss: 0.163415  [51200/60000]
# loss: 0.218768  [57600/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 1.318530
#
# Epoch 48
# -------------------------------
# loss: 0.084976  [    0/60000]
# loss: 0.109356  [ 6400/60000]
# loss: 0.148852  [12800/60000]
# loss: 0.173551  [19200/60000]
# loss: 0.211910  [25600/60000]
# loss: 0.174275  [32000/60000]
# loss: 0.167457  [38400/60000]
# loss: 0.103990  [44800/60000]
# loss: 0.211373  [51200/60000]
# loss: 0.097484  [57600/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 1.398206
#
# Epoch 49
# -------------------------------
# loss: 0.297951  [    0/60000]
# loss: 0.125698  [ 6400/60000]
# loss: 0.196876  [12800/60000]
# loss: 0.126521  [19200/60000]
# loss: 0.342735  [25600/60000]
# loss: 0.165410  [32000/60000]
# loss: 0.145586  [38400/60000]
# loss: 0.196162  [44800/60000]
# loss: 0.181809  [51200/60000]
# loss: 0.147098  [57600/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 1.301199
#
# Epoch 50
# -------------------------------
# loss: 0.127672  [    0/60000]
# loss: 0.115967  [ 6400/60000]
# loss: 0.118384  [12800/60000]
# loss: 0.108125  [19200/60000]
# loss: 1.162420  [25600/60000]
# loss: 0.190935  [32000/60000]
# loss: 0.114715  [38400/60000]
# loss: 0.172931  [44800/60000]
# loss: 0.175064  [51200/60000]
# loss: 0.157152  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 1.262455
#
# Done!

# %%
model = NeuralNetwork()
optimizer_adam = Adam(model.parameters(), lr=LEARNING_RATE)
print('Training with Adam optimizer')
test_loss_adam = run_training(EPOCHS, train_dataloader, test_dataloader, model, nn.CrossEntropyLoss(), optimizer_adam)
# Out:
# Training with Adam optimizer
# Epoch 1
# -------------------------------
# loss: 2.301653  [    0/60000]
# loss: 0.574309  [ 6400/60000]
# loss: 0.382374  [12800/60000]
# loss: 0.515121  [19200/60000]
# loss: 0.449527  [25600/60000]
# loss: 0.438997  [32000/60000]
# loss: 0.379485  [38400/60000]
# loss: 0.542801  [44800/60000]
# loss: 0.476266  [51200/60000]
# loss: 0.517829  [57600/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.430024
#
# Epoch 2
# -------------------------------
# loss: 0.262516  [    0/60000]
# loss: 0.371401  [ 6400/60000]
# loss: 0.294586  [12800/60000]
# loss: 0.411611  [19200/60000]
# loss: 0.387770  [25600/60000]
# loss: 0.358201  [32000/60000]
# loss: 0.298491  [38400/60000]
# loss: 0.476605  [44800/60000]
# loss: 0.437832  [51200/60000]
# loss: 0.457866  [57600/60000]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.404553
#
# Epoch 3
# -------------------------------
# loss: 0.244855  [    0/60000]
# loss: 0.361818  [ 6400/60000]
# loss: 0.250129  [12800/60000]
# loss: 0.347168  [19200/60000]
# loss: 0.353382  [25600/60000]
# loss: 0.333307  [32000/60000]
# loss: 0.258011  [38400/60000]
# loss: 0.426155  [44800/60000]
# loss: 0.329308  [51200/60000]
# loss: 0.376151  [57600/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.383762
#
# Epoch 4
# -------------------------------
# loss: 0.220757  [    0/60000]
# loss: 0.310961  [ 6400/60000]
# loss: 0.227569  [12800/60000]
# loss: 0.311604  [19200/60000]
# loss: 0.372668  [25600/60000]
# loss: 0.313774  [32000/60000]
# loss: 0.237727  [38400/60000]
# loss: 0.343823  [44800/60000]
# loss: 0.312975  [51200/60000]
# loss: 0.325494  [57600/60000]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.373702
#
# Epoch 5
# -------------------------------
# loss: 0.206992  [    0/60000]
# loss: 0.276833  [ 6400/60000]
# loss: 0.212678  [12800/60000]
# loss: 0.278027  [19200/60000]
# loss: 0.331336  [25600/60000]
# loss: 0.291653  [32000/60000]
# loss: 0.236141  [38400/60000]
# loss: 0.337497  [44800/60000]
# loss: 0.272603  [51200/60000]
# loss: 0.300939  [57600/60000]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.360854
#
# Epoch 6
# -------------------------------
# loss: 0.185019  [    0/60000]
# loss: 0.249104  [ 6400/60000]
# loss: 0.208070  [12800/60000]
# loss: 0.223060  [19200/60000]
# loss: 0.339859  [25600/60000]
# loss: 0.275190  [32000/60000]
# loss: 0.222216  [38400/60000]
# loss: 0.295633  [44800/60000]
# loss: 0.235913  [51200/60000]
# loss: 0.351915  [57600/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.352557
#
# Epoch 7
# -------------------------------
# loss: 0.165542  [    0/60000]
# loss: 0.203615  [ 6400/60000]
# loss: 0.191026  [12800/60000]
# loss: 0.229272  [19200/60000]
# loss: 0.335490  [25600/60000]
# loss: 0.233066  [32000/60000]
# loss: 0.229459  [38400/60000]
# loss: 0.260186  [44800/60000]
# loss: 0.228297  [51200/60000]
# loss: 0.301518  [57600/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.347419
#
# Epoch 8
# -------------------------------
# loss: 0.148751  [    0/60000]
# loss: 0.198139  [ 6400/60000]
# loss: 0.212630  [12800/60000]
# loss: 0.197029  [19200/60000]
# loss: 0.327209  [25600/60000]
# loss: 0.260458  [32000/60000]
# loss: 0.204100  [38400/60000]
# loss: 0.245639  [44800/60000]
# loss: 0.183226  [51200/60000]
# loss: 0.296481  [57600/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.348352
#
# Epoch 9
# -------------------------------
# loss: 0.142862  [    0/60000]
# loss: 0.189284  [ 6400/60000]
# loss: 0.223235  [12800/60000]
# loss: 0.211253  [19200/60000]
# loss: 0.303505  [25600/60000]
# loss: 0.238578  [32000/60000]
# loss: 0.212168  [38400/60000]
# loss: 0.233336  [44800/60000]
# loss: 0.200531  [51200/60000]
# loss: 0.270228  [57600/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.351811
#
# Epoch 10
# -------------------------------
# loss: 0.116845  [    0/60000]
# loss: 0.171510  [ 6400/60000]
# loss: 0.184161  [12800/60000]
# loss: 0.185491  [19200/60000]
# loss: 0.282196  [25600/60000]
# loss: 0.260931  [32000/60000]
# loss: 0.192692  [38400/60000]
# loss: 0.210235  [44800/60000]
# loss: 0.179865  [51200/60000]
# loss: 0.263286  [57600/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.372528
#
# Epoch 11
# -------------------------------
# loss: 0.132114  [    0/60000]
# loss: 0.129649  [ 6400/60000]
# loss: 0.200391  [12800/60000]
# loss: 0.190420  [19200/60000]
# loss: 0.313022  [25600/60000]
# loss: 0.231805  [32000/60000]
# loss: 0.151317  [38400/60000]
# loss: 0.234247  [44800/60000]
# loss: 0.206042  [51200/60000]
# loss: 0.257142  [57600/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.376609
#
# Epoch 12
# -------------------------------
# loss: 0.133967  [    0/60000]
# loss: 0.142454  [ 6400/60000]
# loss: 0.174557  [12800/60000]
# loss: 0.195859  [19200/60000]
# loss: 0.245984  [25600/60000]
# loss: 0.244847  [32000/60000]
# loss: 0.203066  [38400/60000]
# loss: 0.180957  [44800/60000]
# loss: 0.145860  [51200/60000]
# loss: 0.230458  [57600/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.396008
#
# Epoch 13
# -------------------------------
# loss: 0.098598  [    0/60000]
# loss: 0.115679  [ 6400/60000]
# loss: 0.130788  [12800/60000]
# loss: 0.165268  [19200/60000]
# loss: 0.283597  [25600/60000]
# loss: 0.184926  [32000/60000]
# loss: 0.147827  [38400/60000]
# loss: 0.220499  [44800/60000]
# loss: 0.202658  [51200/60000]
# loss: 0.213905  [57600/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.423673
#
# Epoch 14
# -------------------------------
# loss: 0.101276  [    0/60000]
# loss: 0.111528  [ 6400/60000]
# loss: 0.156291  [12800/60000]
# loss: 0.187506  [19200/60000]
# loss: 0.215221  [25600/60000]
# loss: 0.203125  [32000/60000]
# loss: 0.149469  [38400/60000]
# loss: 0.209357  [44800/60000]
# loss: 0.159581  [51200/60000]
# loss: 0.189865  [57600/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.411126
#
# Epoch 15
# -------------------------------
# loss: 0.090471  [    0/60000]
# loss: 0.092724  [ 6400/60000]
# loss: 0.201008  [12800/60000]
# loss: 0.134302  [19200/60000]
# loss: 0.175620  [25600/60000]
# loss: 0.175080  [32000/60000]
# loss: 0.160517  [38400/60000]
# loss: 0.184316  [44800/60000]
# loss: 0.139569  [51200/60000]
# loss: 0.183589  [57600/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.410818
#
# Epoch 16
# -------------------------------
# loss: 0.101027  [    0/60000]
# loss: 0.117066  [ 6400/60000]
# loss: 0.197405  [12800/60000]
# loss: 0.164918  [19200/60000]
# loss: 0.204272  [25600/60000]
# loss: 0.164644  [32000/60000]
# loss: 0.128721  [38400/60000]
# loss: 0.173758  [44800/60000]
# loss: 0.102155  [51200/60000]
# loss: 0.168790  [57600/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.449089
#
# Epoch 17
# -------------------------------
# loss: 0.178519  [    0/60000]
# loss: 0.113186  [ 6400/60000]
# loss: 0.186518  [12800/60000]
# loss: 0.150579  [19200/60000]
# loss: 0.182512  [25600/60000]
# loss: 0.201614  [32000/60000]
# loss: 0.095201  [38400/60000]
# loss: 0.193682  [44800/60000]
# loss: 0.110573  [51200/60000]
# loss: 0.162112  [57600/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.431375
#
# Epoch 18
# -------------------------------
# loss: 0.087964  [    0/60000]
# loss: 0.128918  [ 6400/60000]
# loss: 0.166936  [12800/60000]
# loss: 0.138780  [19200/60000]
# loss: 0.121957  [25600/60000]
# loss: 0.146450  [32000/60000]
# loss: 0.147038  [38400/60000]
# loss: 0.177477  [44800/60000]
# loss: 0.162429  [51200/60000]
# loss: 0.200953  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.465634
#
# Epoch 19
# -------------------------------
# loss: 0.096862  [    0/60000]
# loss: 0.126897  [ 6400/60000]
# loss: 0.174314  [12800/60000]
# loss: 0.135603  [19200/60000]
# loss: 0.139404  [25600/60000]
# loss: 0.241544  [32000/60000]
# loss: 0.137327  [38400/60000]
# loss: 0.191666  [44800/60000]
# loss: 0.122886  [51200/60000]
# loss: 0.197443  [57600/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.456377
#
# Epoch 20
# -------------------------------
# loss: 0.106539  [    0/60000]
# loss: 0.103264  [ 6400/60000]
# loss: 0.170835  [12800/60000]
# loss: 0.095030  [19200/60000]
# loss: 0.144034  [25600/60000]
# loss: 0.202458  [32000/60000]
# loss: 0.086698  [38400/60000]
# loss: 0.230742  [44800/60000]
# loss: 0.124714  [51200/60000]
# loss: 0.153167  [57600/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.493909
#
# Epoch 21
# -------------------------------
# loss: 0.077348  [    0/60000]
# loss: 0.098785  [ 6400/60000]
# loss: 0.133367  [12800/60000]
# loss: 0.103998  [19200/60000]
# loss: 0.137292  [25600/60000]
# loss: 0.208556  [32000/60000]
# loss: 0.130983  [38400/60000]
# loss: 0.177573  [44800/60000]
# loss: 0.092920  [51200/60000]
# loss: 0.152446  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.484995
#
# Epoch 22
# -------------------------------
# loss: 0.080027  [    0/60000]
# loss: 0.098949  [ 6400/60000]
# loss: 0.171330  [12800/60000]
# loss: 0.108505  [19200/60000]
# loss: 0.112960  [25600/60000]
# loss: 0.147547  [32000/60000]
# loss: 0.059096  [38400/60000]
# loss: 0.139188  [44800/60000]
# loss: 0.143801  [51200/60000]
# loss: 0.185231  [57600/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.532071
#
# Epoch 23
# -------------------------------
# loss: 0.051486  [    0/60000]
# loss: 0.084518  [ 6400/60000]
# loss: 0.123545  [12800/60000]
# loss: 0.082704  [19200/60000]
# loss: 0.121746  [25600/60000]
# loss: 0.147467  [32000/60000]
# loss: 0.114408  [38400/60000]
# loss: 0.258323  [44800/60000]
# loss: 0.163828  [51200/60000]
# loss: 0.212590  [57600/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.535909
#
# Epoch 24
# -------------------------------
# loss: 0.195624  [    0/60000]
# loss: 0.073298  [ 6400/60000]
# loss: 0.079816  [12800/60000]
# loss: 0.091957  [19200/60000]
# loss: 0.131893  [25600/60000]
# loss: 0.136582  [32000/60000]
# loss: 0.069816  [38400/60000]
# loss: 0.125845  [44800/60000]
# loss: 0.085674  [51200/60000]
# loss: 0.202806  [57600/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.544873
#
# Epoch 25
# -------------------------------
# loss: 0.093543  [    0/60000]
# loss: 0.077435  [ 6400/60000]
# loss: 0.102178  [12800/60000]
# loss: 0.071041  [19200/60000]
# loss: 0.168600  [25600/60000]
# loss: 0.113835  [32000/60000]
# loss: 0.088093  [38400/60000]
# loss: 0.109909  [44800/60000]
# loss: 0.047234  [51200/60000]
# loss: 0.218099  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.519425
#
# Epoch 26
# -------------------------------
# loss: 0.062941  [    0/60000]
# loss: 0.071105  [ 6400/60000]
# loss: 0.086299  [12800/60000]
# loss: 0.084696  [19200/60000]
# loss: 0.101973  [25600/60000]
# loss: 0.103362  [32000/60000]
# loss: 0.098905  [38400/60000]
# loss: 0.153856  [44800/60000]
# loss: 0.107877  [51200/60000]
# loss: 0.211958  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.567326
#
# Epoch 27
# -------------------------------
# loss: 0.070103  [    0/60000]
# loss: 0.044997  [ 6400/60000]
# loss: 0.144792  [12800/60000]
# loss: 0.089930  [19200/60000]
# loss: 0.112497  [25600/60000]
# loss: 0.137860  [32000/60000]
# loss: 0.162671  [38400/60000]
# loss: 0.097432  [44800/60000]
# loss: 0.062815  [51200/60000]
# loss: 0.151400  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.600357
#
# Epoch 28
# -------------------------------
# loss: 0.127792  [    0/60000]
# loss: 0.060442  [ 6400/60000]
# loss: 0.078426  [12800/60000]
# loss: 0.047520  [19200/60000]
# loss: 0.102498  [25600/60000]
# loss: 0.156976  [32000/60000]
# loss: 0.043876  [38400/60000]
# loss: 0.257764  [44800/60000]
# loss: 0.048323  [51200/60000]
# loss: 0.122752  [57600/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.587839
#
# Epoch 29
# -------------------------------
# loss: 0.098985  [    0/60000]
# loss: 0.052760  [ 6400/60000]
# loss: 0.056157  [12800/60000]
# loss: 0.062053  [19200/60000]
# loss: 0.125113  [25600/60000]
# loss: 0.071865  [32000/60000]
# loss: 0.060458  [38400/60000]
# loss: 0.097859  [44800/60000]
# loss: 0.226580  [51200/60000]
# loss: 0.177313  [57600/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.636394
#
# Epoch 30
# -------------------------------
# loss: 0.105363  [    0/60000]
# loss: 0.045287  [ 6400/60000]
# loss: 0.087169  [12800/60000]
# loss: 0.078440  [19200/60000]
# loss: 0.080810  [25600/60000]
# loss: 0.085658  [32000/60000]
# loss: 0.082823  [38400/60000]
# loss: 0.120353  [44800/60000]
# loss: 0.130304  [51200/60000]
# loss: 0.196108  [57600/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.609178
#
# Epoch 31
# -------------------------------
# loss: 0.063514  [    0/60000]
# loss: 0.052648  [ 6400/60000]
# loss: 0.133189  [12800/60000]
# loss: 0.068406  [19200/60000]
# loss: 0.106031  [25600/60000]
# loss: 0.063060  [32000/60000]
# loss: 0.083296  [38400/60000]
# loss: 0.069439  [44800/60000]
# loss: 0.085771  [51200/60000]
# loss: 0.195297  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.660282
#
# Epoch 32
# -------------------------------
# loss: 0.106671  [    0/60000]
# loss: 0.053997  [ 6400/60000]
# loss: 0.136392  [12800/60000]
# loss: 0.054364  [19200/60000]
# loss: 0.130362  [25600/60000]
# loss: 0.061306  [32000/60000]
# loss: 0.058019  [38400/60000]
# loss: 0.060651  [44800/60000]
# loss: 0.049542  [51200/60000]
# loss: 0.120287  [57600/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.585028
#
# Epoch 33
# -------------------------------
# loss: 0.043554  [    0/60000]
# loss: 0.052562  [ 6400/60000]
# loss: 0.156037  [12800/60000]
# loss: 0.125775  [19200/60000]
# loss: 0.097339  [25600/60000]
# loss: 0.086873  [32000/60000]
# loss: 0.104967  [38400/60000]
# loss: 0.044309  [44800/60000]
# loss: 0.070834  [51200/60000]
# loss: 0.159604  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.631891
#
# Epoch 34
# -------------------------------
# loss: 0.036339  [    0/60000]
# loss: 0.081310  [ 6400/60000]
# loss: 0.053334  [12800/60000]
# loss: 0.075494  [19200/60000]
# loss: 0.054665  [25600/60000]
# loss: 0.060803  [32000/60000]
# loss: 0.062535  [38400/60000]
# loss: 0.135962  [44800/60000]
# loss: 0.071261  [51200/60000]
# loss: 0.112393  [57600/60000]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.646669
#
# Epoch 35
# -------------------------------
# loss: 0.044156  [    0/60000]
# loss: 0.086893  [ 6400/60000]
# loss: 0.047071  [12800/60000]
# loss: 0.041129  [19200/60000]
# loss: 0.071383  [25600/60000]
# loss: 0.083334  [32000/60000]
# loss: 0.060123  [38400/60000]
# loss: 0.067435  [44800/60000]
# loss: 0.086132  [51200/60000]
# loss: 0.103969  [57600/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.647424
#
# Epoch 36
# -------------------------------
# loss: 0.089037  [    0/60000]
# loss: 0.093241  [ 6400/60000]
# loss: 0.041854  [12800/60000]
# loss: 0.073941  [19200/60000]
# loss: 0.043974  [25600/60000]
# loss: 0.068104  [32000/60000]
# loss: 0.036139  [38400/60000]
# loss: 0.164623  [44800/60000]
# loss: 0.031759  [51200/60000]
# loss: 0.147094  [57600/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.637572
#
# Epoch 37
# -------------------------------
# loss: 0.071557  [    0/60000]
# loss: 0.129486  [ 6400/60000]
# loss: 0.062354  [12800/60000]
# loss: 0.064797  [19200/60000]
# loss: 0.107787  [25600/60000]
# loss: 0.043536  [32000/60000]
# loss: 0.050880  [38400/60000]
# loss: 0.160012  [44800/60000]
# loss: 0.131074  [51200/60000]
# loss: 0.090963  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.729811
#
# Epoch 38
# -------------------------------
# loss: 0.031208  [    0/60000]
# loss: 0.047507  [ 6400/60000]
# loss: 0.103208  [12800/60000]
# loss: 0.054903  [19200/60000]
# loss: 0.045208  [25600/60000]
# loss: 0.084772  [32000/60000]
# loss: 0.078124  [38400/60000]
# loss: 0.050377  [44800/60000]
# loss: 0.015161  [51200/60000]
# loss: 0.112934  [57600/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.674927
#
# Epoch 39
# -------------------------------
# loss: 0.075594  [    0/60000]
# loss: 0.048606  [ 6400/60000]
# loss: 0.042769  [12800/60000]
# loss: 0.050704  [19200/60000]
# loss: 0.038960  [25600/60000]
# loss: 0.089990  [32000/60000]
# loss: 0.091717  [38400/60000]
# loss: 0.073339  [44800/60000]
# loss: 0.252465  [51200/60000]
# loss: 0.103990  [57600/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.650622
#
# Epoch 40
# -------------------------------
# loss: 0.050716  [    0/60000]
# loss: 0.017889  [ 6400/60000]
# loss: 0.076759  [12800/60000]
# loss: 0.044295  [19200/60000]
# loss: 0.053000  [25600/60000]
# loss: 0.076405  [32000/60000]
# loss: 0.060750  [38400/60000]
# loss: 0.135489  [44800/60000]
# loss: 0.038688  [51200/60000]
# loss: 0.132290  [57600/60000]
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.687539
#
# Epoch 41
# -------------------------------
# loss: 0.055854  [    0/60000]
# loss: 0.036326  [ 6400/60000]
# loss: 0.018651  [12800/60000]
# loss: 0.072024  [19200/60000]
# loss: 0.091654  [25600/60000]
# loss: 0.093462  [32000/60000]
# loss: 0.102002  [38400/60000]
# loss: 0.093116  [44800/60000]
# loss: 0.031258  [51200/60000]
# loss: 0.141504  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.679046
#
# Epoch 42
# -------------------------------
# loss: 0.042490  [    0/60000]
# loss: 0.096805  [ 6400/60000]
# loss: 0.118449  [12800/60000]
# loss: 0.108135  [19200/60000]
# loss: 0.089647  [25600/60000]
# loss: 0.103961  [32000/60000]
# loss: 0.053398  [38400/60000]
# loss: 0.113430  [44800/60000]
# loss: 0.042765  [51200/60000]
# loss: 0.063707  [57600/60000]
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.687251
#
# Epoch 43
# -------------------------------
# loss: 0.065787  [    0/60000]
# loss: 0.137674  [ 6400/60000]
# loss: 0.042130  [12800/60000]
# loss: 0.094189  [19200/60000]
# loss: 0.037194  [25600/60000]
# loss: 0.042579  [32000/60000]
# loss: 0.043304  [38400/60000]
# loss: 0.072942  [44800/60000]
# loss: 0.026322  [51200/60000]
# loss: 0.078177  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.700482
#
# Epoch 44
# -------------------------------
# loss: 0.081087  [    0/60000]
# loss: 0.031045  [ 6400/60000]
# loss: 0.110892  [12800/60000]
# loss: 0.075929  [19200/60000]
# loss: 0.111170  [25600/60000]
# loss: 0.134363  [32000/60000]
# loss: 0.078806  [38400/60000]
# loss: 0.062431  [44800/60000]
# loss: 0.364099  [51200/60000]
# loss: 0.125396  [57600/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.690227
#
# Epoch 45
# -------------------------------
# loss: 0.062575  [    0/60000]
# loss: 0.058358  [ 6400/60000]
# loss: 0.070546  [12800/60000]
# loss: 0.085127  [19200/60000]
# loss: 0.026235  [25600/60000]
# loss: 0.052123  [32000/60000]
# loss: 0.028453  [38400/60000]
# loss: 0.021517  [44800/60000]
# loss: 0.049792  [51200/60000]
# loss: 0.104127  [57600/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.711102
#
# Epoch 46
# -------------------------------
# loss: 0.065335  [    0/60000]
# loss: 0.058085  [ 6400/60000]
# loss: 0.026545  [12800/60000]
# loss: 0.097789  [19200/60000]
# loss: 0.066952  [25600/60000]
# loss: 0.062020  [32000/60000]
# loss: 0.030804  [38400/60000]
# loss: 0.071797  [44800/60000]
# loss: 0.071969  [51200/60000]
# loss: 0.192307  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.720455
#
# Epoch 47
# -------------------------------
# loss: 0.050272  [    0/60000]
# loss: 0.021705  [ 6400/60000]
# loss: 0.035604  [12800/60000]
# loss: 0.040224  [19200/60000]
# loss: 0.033035  [25600/60000]
# loss: 0.104568  [32000/60000]
# loss: 0.036242  [38400/60000]
# loss: 0.014224  [44800/60000]
# loss: 0.016759  [51200/60000]
# loss: 0.051716  [57600/60000]
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.714810
#
# Epoch 48
# -------------------------------
# loss: 0.069657  [    0/60000]
# loss: 0.012423  [ 6400/60000]
# loss: 0.023757  [12800/60000]
# loss: 0.056307  [19200/60000]
# loss: 0.017455  [25600/60000]
# loss: 0.073628  [32000/60000]
# loss: 0.024565  [38400/60000]
# loss: 0.032028  [44800/60000]
# loss: 0.020256  [51200/60000]
# loss: 0.049901  [57600/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.808427
#
# Epoch 49
# -------------------------------
# loss: 0.035029  [    0/60000]
# loss: 0.027456  [ 6400/60000]
# loss: 0.089638  [12800/60000]
# loss: 0.058104  [19200/60000]
# loss: 0.090680  [25600/60000]
# loss: 0.027181  [32000/60000]
# loss: 0.043535  [38400/60000]
# loss: 0.021342  [44800/60000]
# loss: 0.098912  [51200/60000]
# loss: 0.056804  [57600/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.794553
#
# Epoch 50
# -------------------------------
# loss: 0.044811  [    0/60000]
# loss: 0.092117  [ 6400/60000]
# loss: 0.016015  [12800/60000]
# loss: 0.049710  [19200/60000]
# loss: 0.132976  [25600/60000]
# loss: 0.045054  [32000/60000]
# loss: 0.071405  [38400/60000]
# loss: 0.186442  [44800/60000]
# loss: 0.084344  [51200/60000]
# loss: 0.052843  [57600/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.760502
#
# Done!

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, EPOCHS + 1), test_loss_sgd, label='SGD')
plt.plot(range(1, EPOCHS + 1), test_loss_rms, label='RMSprop')
plt.plot(range(1, EPOCHS + 1), test_loss_adam, label='Adam')
plt.xlabel('Epochs')
plt.ylabel('Test Loss')
plt.title('Convergence Comparison of SGD, RMSprop and Adam')
plt.grid(True)
plt.legend()
plt.show()
